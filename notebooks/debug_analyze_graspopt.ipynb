# %%
import numpy as np

import plotly

# %%
datapath = "/home/ninad/Datasets/MMDemo/newtest/opt_grasp.npz"
data = np.load(datapath)

# %%
data.keys()

# %%
cmap_goal = data['cmap_goal']
cmap_goal.shape

# %%
econ = data['energy_con']

# %%
epen = data['energy_pen']

# %%
econ.shape

# %%
econ[:, -1]

# %%
econ[:, 0]

# %%
epen[:, -1]

# %%
epen[:, 0]
